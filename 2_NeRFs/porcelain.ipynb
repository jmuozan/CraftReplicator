# %%
# Disable PyTorch dynamo to avoid circular import issues with Python 3.13
import os
os.environ["PYTORCH_DISABLE_DYNAMO"] = "1"

import torch
import torch.nn as nn
import numpy as np
import imageio
import matplotlib.pyplot as plt
import json
from torch.utils.data import DataLoader
from dataset import get_rays
from rendering import rendering
from model import Voxels, Nerf
from ml_helpers import training

# Configuration - Change these values as needed
dataset_name = "porcelain"  # Dataset folder name
hidden_dim = 256            # Hidden dimension size for NeRF model
epochs = 4                  # Number of training epochs
warmup_epochs = 1           # Number of warmup epochs
batch_size = 1024           # Batch size for training
learning_rate = 5e-4        # Learning rate
output_dir = "output"       # Output directory for saved models

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)
model_save_path = os.path.join(output_dir, f'{dataset_name}_nerf_model.pth')
checkpoint_path = os.path.join(output_dir, f'{dataset_name}_nerf_checkpoint.pth')

print("torch version: ", torch.__version__)
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print("device: ", device)

# Analyze dataset to determine appropriate rendering parameters
def analyze_scene_scale(dataset_name):
    """Analyze the scene scale from transforms.json to set appropriate tn/tf values"""
    transforms_path = os.path.join(dataset_name, 'transforms.json')
    if not os.path.exists(transforms_path):
        transforms_path = 'transforms.json'
        if not os.path.exists(transforms_path):
            print(f"Warning: Could not find transforms.json for {dataset_name}")
            return 0.1, 6.0  # Default values
    
    with open(transforms_path, 'r') as f:
        transforms = json.load(f)
    
    # Extract camera positions
    camera_positions = []
    for frame in transforms['frames']:
        c2w = np.array(frame['transform_matrix'], dtype=np.float32)
        pos = c2w[:3, 3]
        camera_positions.append(pos)
    
    camera_positions = np.array(camera_positions, dtype=np.float32)
    
    # Calculate distances from origin
    origin_distances = np.linalg.norm(camera_positions, axis=1)
    
    # Set near/far thresholds based on scene scale
    tn = max(0.1, origin_distances.min() * 0.5)  # Near threshold
    tf = origin_distances.max() * 1.5  # Far threshold
    
    print(f"Dataset: {dataset_name}")
    print(f"Camera distance from origin - min: {origin_distances.min():.2f}, max: {origin_distances.max():.2f}")
    print(f"Using tn={tn:.2f}, tf={tf:.2f}")
    
    return tn, tf

# Set the near and far thresholds based on dataset analysis
tn, tf = analyze_scene_scale(dataset_name)

# Load training rays from transforms.json
print(f"Loading {dataset_name} dataset...")
o, d, target_px_values = get_rays(dataset_name, mode='train')
print(f"Loaded {o.shape[0]} training images with resolution {o.shape[1]} pixels")

# Create data loaders for full and cropped images
# Force float32 to avoid MPS issues
dataloader = DataLoader(torch.cat((
    torch.from_numpy(o.astype(np.float32)).reshape(-1, 3),
    torch.from_numpy(d.astype(np.float32)).reshape(-1, 3),
    torch.from_numpy(target_px_values.astype(np.float32)).reshape(-1, 3)), dim=1),
    batch_size=batch_size, shuffle=True)

# For warmup training, use a center crop of the images
img_size = int(np.sqrt(o.shape[1]))  # Assuming square images
o_reshaped = o.reshape(o.shape[0], img_size, img_size, 3)
d_reshaped = d.reshape(d.shape[0], img_size, img_size, 3)
target_reshaped = target_px_values.reshape(target_px_values.shape[0], img_size, img_size, 3)

# Create a center crop (adjust crop size as needed)
crop_start = img_size // 4
crop_end = img_size - crop_start
o_cropped = o_reshaped[:, crop_start:crop_end, crop_start:crop_end, :].astype(np.float32)
d_cropped = d_reshaped[:, crop_start:crop_end, crop_start:crop_end, :].astype(np.float32)
target_cropped = target_reshaped[:, crop_start:crop_end, crop_start:crop_end, :].astype(np.float32)

dataloader_warmup = DataLoader(torch.cat((
    torch.from_numpy(o_cropped).reshape(-1, 3),
    torch.from_numpy(d_cropped).reshape(-1, 3),
    torch.from_numpy(target_cropped).reshape(-1, 3)), dim=1),
    batch_size=batch_size, shuffle=True)

# Load test rays for evaluation
try:
    test_o, test_d, test_target_px_values = get_rays(dataset_name, mode='test')
    print(f"Loaded {test_o.shape[0]} test images")
    has_test_data = True
except Exception as e:
    print(f"No test data found: {e}")
    print("Will use a portion of training data for evaluation")
    # Use some training images for testing if no test data is available
    test_o = o[:min(5, o.shape[0])]
    test_d = d[:min(5, d.shape[0])]
    test_target_px_values = target_px_values[:min(5, target_px_values.shape[0])]
    has_test_data = False

# Initialize the NeRF model with more capacity
# Important fix for PyTorch 2.x compatibility in Python 3.13
import sys
if sys.version_info >= (3, 13):
    import torch._dynamo
    if not hasattr(torch._dynamo, 'config'):
        torch._dynamo.config = type('', (), {})()
        torch._dynamo.config.suppress_errors = True

# Initialize model and optimizer
model = Nerf(hidden_dim=hidden_dim, Lpos=10, Ldir=4).to(device)

# Wrap model creation and optimizer in a try-except block to handle potential errors
try:
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(
        optimizer, 
        milestones=[epochs // 3, epochs * 2 // 3], 
        gamma=0.5
    )
except Exception as e:
    print(f"Error creating optimizer: {e}")
    print("Trying alternative optimizer setup...")
    # Alternative approach without dynamic loading
    params = list(model.parameters())
    optimizer = torch.optim.Adam(params, lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=epochs // 2, gamma=0.5)

# Training: First warmup with cropped images
if warmup_epochs > 0:
    print("Starting warmup training with cropped images...")
    nb_bins = 100  # Number of sample points along each ray
    warmup_training_loss = training(model, optimizer, scheduler, tn, tf, nb_bins, warmup_epochs, dataloader_warmup, device=device)
    plt.figure(figsize=(10, 5))
    plt.plot(warmup_training_loss)
    plt.title("Warmup Training Loss")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.savefig(os.path.join(output_dir, f"{dataset_name}_warmup_loss.png"))
    plt.show()

# Continue training with full images
print("Starting main training with full images...")
nb_bins = 128  # Increase the number of bins for better sampling
training_loss = training(model, optimizer, scheduler, tn, tf, nb_bins, epochs, dataloader, device=device)
plt.figure(figsize=(10, 5))
plt.plot(training_loss)
plt.title("Full Training Loss")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.savefig(os.path.join(output_dir, f"{dataset_name}_training_loss.png"))
plt.show()

# Save a checkpoint after training
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'training_loss': training_loss,
    'tn': tn,
    'tf': tf,
    'nb_bins': nb_bins,
    'dataset': dataset_name
}, checkpoint_path)

# Save the model weights
torch.save(model.state_dict(), model_save_path)
print(f"Model weights saved to '{model_save_path}'")

# Render a test image for visual evaluation
def visualize_test_image(idx=0):
    with torch.no_grad():
        test_batch_size = 4096
        test_idx = idx
        test_h = int(np.sqrt(test_o.shape[1]))
        test_w = test_h
        
        # Get rays for a single test image - explicitly cast to float32
        o_test = torch.from_numpy(test_o[test_idx].astype(np.float32)).to(device)
        d_test = torch.from_numpy(test_d[test_idx].astype(np.float32)).to(device)
        
        # Print information about the test rays
        print(f"Test image {idx}: Ray origins shape: {o_test.shape}")
        print(f"Ray origins range: min={o_test.min().item():.4f}, max={o_test.max().item():.4f}")
        
        # Render in batches to avoid OOM
        img_rendered = []
        for i in range(0, test_h * test_w, test_batch_size):
            end = min(i + test_batch_size, test_h * test_w)
            rendered_batch = rendering(model, o_test[i:end], d_test[i:end], tn, tf, nb_bins, device)
            img_rendered.append(rendered_batch)
            
            # Check if rendering is producing reasonable values
            if i == 0:
                print(f"First render batch stats: min={rendered_batch.min().item():.4f}, max={rendered_batch.max().item():.4f}")
            
        img_rendered = torch.cat(img_rendered, dim=0)
        img_rendered = img_rendered.reshape(test_h, test_w, 3).cpu().numpy()
        
        # Get the ground truth image
        img_truth = test_target_px_values[test_idx].reshape(test_h, test_w, 3)
        
        # Save and display rendered vs ground truth
        plt.figure(figsize=(15, 7))
        plt.subplot(1, 2, 1)
        plt.imshow(np.clip(img_rendered, 0, 1))  # Clip values to valid range
        plt.title("Rendered")
        plt.subplot(1, 2, 2)
        plt.imshow(img_truth)
        plt.title("Ground Truth")
        plt.tight_layout()
        plt.savefig(os.path.join(output_dir, f"{dataset_name}_test_render_{idx}.png"))
        plt.show()
        
        # Also show the render with different adjustments
        plt.figure(figsize=(15, 5))
        plt.subplot(1, 3, 1)
        plt.imshow(np.clip(img_rendered, 0, 1))
        plt.title("Original Render")
        
        plt.subplot(1, 3, 2)
        plt.imshow(np.clip(img_rendered ** 0.45, 0, 1))  # Gamma correction
        plt.title("Gamma Corrected")
        
        plt.subplot(1, 3, 3)
        # Normalize to use full dynamic range
        normalized = (img_rendered - img_rendered.min()) / (img_rendered.max() - img_rendered.min() + 1e-8)
        plt.imshow(normalized)
        plt.title("Normalized")
        
        plt.tight_layout()
        plt.savefig(os.path.join(output_dir, f"{dataset_name}_test_render_{idx}_adjustments.png"))
        plt.show()

# Debug ray generation
def debug_ray_generation():
    # Load a single test image and visualize the ray distribution
    test_idx = 0
    test_h = int(np.sqrt(test_o.shape[1]))
    test_w = test_h
    
    # Print ray statistics
    print(f"Ray origins min: {test_o.min()}, max: {test_o.max()}")
    print(f"Ray directions min: {test_d.min()}, max: {test_d.max()}")
    
    # Check if ray directions are normalized
    ray_lengths = np.linalg.norm(test_d, axis=-1)
    print(f"Ray direction lengths: min={ray_lengths.min()}, max={ray_lengths.max()}")
    
    # Visualize ray origins and directions
    plt.figure(figsize=(12, 5))
    
    # Plot ray origins
    plt.subplot(1, 2, 1)
    plt.scatter(test_o[test_idx, ::100, 0], test_o[test_idx, ::100, 2], alpha=0.5, s=1)
    plt.title("Ray Origins (Top-Down)")
    plt.xlabel("X")
    plt.ylabel("Z")
    plt.axis('equal')
    
    # Plot ray directions (from the center pixel)
    center_idx = test_h // 2 * test_w + test_w // 2
    plt.subplot(1, 2, 2)
    plt.quiver(test_o[test_idx, center_idx, 0].astype(np.float32), 
               test_o[test_idx, center_idx, 2].astype(np.float32),
               test_d[test_idx, center_idx, 0].astype(np.float32), 
               test_d[test_idx, center_idx, 2].astype(np.float32),
               angles='xy', scale_units='xy', scale=0.1)
    plt.title("Center Ray Direction")
    plt.xlabel("X")
    plt.ylabel("Z")
    plt.axis('equal')
    
    plt.tight_layout()
    plt.savefig(os.path.join(output_dir, f"{dataset_name}_ray_debug.png"))
    plt.show()

# Run debug and visualization
debug_ray_generation()
print("Rendering test image...")
visualize_test_image(0)
print("Training and evaluation complete!")
print(f"Model saved to: {model_save_path}")
# Out:
# usage: ipykernel_launcher.py [-h] [--dataset DATASET] [--epochs EPOCHS]
#                              [--warmup_epochs WARMUP_EPOCHS]
#                              [--hidden_dim HIDDEN_DIM]
#                              [--batch_size BATCH_SIZE] [--lr LR]
#                              [--output_dir OUTPUT_DIR]
# ipykernel_launcher.py: error: unrecognized arguments: --f=/Users/jorgemuyo/Library/Jupyter/runtime/kernel-v334e4aea122febe3efd6ecc2a0f4c911fb7eb492b.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /Users/jorgemuyo/miniforge3/envs/NeRF/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import torch
import torch.nn as nn
import numpy as np
import os
import imageio
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from dataset import get_rays
from rendering import rendering
from model import Voxels, Nerf
from ml_helpers import training

print("torch version: ", torch.__version__)
if torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print("device: ", device)

# Set the near and far thresholds for rendering
# These values need to match the scale in transforms.json
# For the fox dataset in transforms.json, the cameras are approximately at distance 3-4 units
tn = 0.1  # Near threshold - much closer to capture details near camera
tf = 6.0  # Far threshold - covers the full scene

# Load training rays from transforms.json
batch_size = 1024
o, d, target_px_values = get_rays('fox', mode='train')
print(f"Loaded {o.shape[0]} training images with resolution {o.shape[1]} pixels")

# Create data loaders for full and cropped images
# Force float32 to avoid MPS issues
dataloader = DataLoader(torch.cat((
    torch.from_numpy(o.astype(np.float32)).reshape(-1, 3),
    torch.from_numpy(d.astype(np.float32)).reshape(-1, 3),
    torch.from_numpy(target_px_values.astype(np.float32)).reshape(-1, 3)), dim=1),
    batch_size=batch_size, shuffle=True)

# For warmup training, use a center crop of the images
img_size = int(np.sqrt(o.shape[1]))  # Assuming square images
o_reshaped = o.reshape(o.shape[0], img_size, img_size, 3)
d_reshaped = d.reshape(d.shape[0], img_size, img_size, 3)
target_reshaped = target_px_values.reshape(target_px_values.shape[0], img_size, img_size, 3)

# Create a center crop (adjust crop size as needed)
crop_start = img_size // 4
crop_end = img_size - crop_start
o_cropped = o_reshaped[:, crop_start:crop_end, crop_start:crop_end, :].astype(np.float32)
d_cropped = d_reshaped[:, crop_start:crop_end, crop_start:crop_end, :].astype(np.float32)
target_cropped = target_reshaped[:, crop_start:crop_end, crop_start:crop_end, :].astype(np.float32)

dataloader_warmup = DataLoader(torch.cat((
    torch.from_numpy(o_cropped).reshape(-1, 3),
    torch.from_numpy(d_cropped).reshape(-1, 3),
    torch.from_numpy(target_cropped).reshape(-1, 3)), dim=1),
    batch_size=batch_size, shuffle=True)

# Load test rays for evaluation
test_o, test_d, test_target_px_values = get_rays('fox', mode='test')
print(f"Loaded {test_o.shape[0]} test images")

# Initialize the NeRF model with more capacity
model = Nerf(hidden_dim=256, Lpos=10, Ldir=4).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)  # Lower learning rate for stability
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[2, 4, 6], gamma=0.5)

# Training: First warmup with cropped images
print("Starting warmup training with cropped images...")
nb_bins = 100  # Number of sample points along each ray
training_loss = training(model, optimizer, scheduler, tn, tf, nb_bins, 1, dataloader_warmup, device=device)
plt.figure(figsize=(10, 5))
plt.plot(training_loss)
plt.title("Warmup Training Loss")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.show()

# Continue training with full images
print("Starting main training with full images...")
nb_epochs = 1
nb_bins = 128  # Increase the number of bins for better sampling
training_loss = training(model, optimizer, scheduler, tn, tf, nb_bins, nb_epochs, dataloader, device=device)
plt.figure(figsize=(10, 5))
plt.plot(training_loss)
plt.title("Full Training Loss")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.show()

# Save a checkpoint after each epoch to monitor progress
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'training_loss': training_loss,
    'tn': tn,
    'tf': tf,
    'nb_bins': nb_bins
}, 'nerf_checkpoint.pth')

# Save the model weights
torch.save(model.state_dict(), 'nerf_model_weights.pth')
print("Model weights saved to 'nerf_model_weights.pth'")

# Render a test image for visual evaluation
def visualize_test_image(idx=0):
    with torch.no_grad():
        test_batch_size = 4096
        test_idx = idx
        test_h = int(np.sqrt(test_o.shape[1]))
        test_w = test_h
        
        # Get rays for a single test image - explicitly cast to float32
        o_test = torch.from_numpy(test_o[test_idx].astype(np.float32)).to(device)
        d_test = torch.from_numpy(test_d[test_idx].astype(np.float32)).to(device)
        
        # Print information about the test rays
        print(f"Test image {idx}: Ray origins shape: {o_test.shape}")
        print(f"Ray origins range: min={o_test.min().item():.4f}, max={o_test.max().item():.4f}")
        
        # Render in batches to avoid OOM
        img_rendered = []
        for i in range(0, test_h * test_w, test_batch_size):
            end = min(i + test_batch_size, test_h * test_w)
            rendered_batch = rendering(model, o_test[i:end], d_test[i:end], tn, tf, nb_bins, device)
            img_rendered.append(rendered_batch)
            
            # Check if rendering is producing reasonable values
            if i == 0:
                print(f"First render batch stats: min={rendered_batch.min().item():.4f}, max={rendered_batch.max().item():.4f}")
            
        img_rendered = torch.cat(img_rendered, dim=0)
        img_rendered = img_rendered.reshape(test_h, test_w, 3).cpu().numpy()
        
        # Get the ground truth image
        img_truth = test_target_px_values[test_idx].reshape(test_h, test_w, 3)
        
        # Display rendered vs ground truth
        plt.figure(figsize=(15, 7))
        plt.subplot(1, 2, 1)
        plt.imshow(np.clip(img_rendered, 0, 1))  # Clip values to valid range
        plt.title("Rendered")
        plt.subplot(1, 2, 2)
        plt.imshow(img_truth)
        plt.title("Ground Truth")
        plt.tight_layout()
        plt.show()
        
        # Also try showing the render with different gamma correction in case it's just very dark
        plt.figure(figsize=(15, 5))
        plt.subplot(1, 3, 1)
        plt.imshow(np.clip(img_rendered, 0, 1))
        plt.title("Original Render")
        
        plt.subplot(1, 3, 2)
        plt.imshow(np.clip(img_rendered ** 0.45, 0, 1))  # Gamma correction
        plt.title("Gamma Corrected")
        
        plt.subplot(1, 3, 3)
        # Normalize to use full dynamic range
        normalized = (img_rendered - img_rendered.min()) / (img_rendered.max() - img_rendered.min() + 1e-8)
        plt.imshow(normalized)
        plt.title("Normalized")
        
        plt.tight_layout()
        plt.show()
        
        # Save the rendered image - this can help diagnose issues
        plt.imsave(f'test_render_{idx}.png', np.clip(img_rendered, 0, 1))

# Add a debugging function to check the ray generation
def debug_ray_generation():
    # Load a single test image and visualize the ray distribution
    test_idx = 0
    test_h = int(np.sqrt(test_o.shape[1]))
    test_w = test_h
    
    # Print ray statistics
    print(f"Ray origins min: {test_o.min()}, max: {test_o.max()}")
    print(f"Ray directions min: {test_d.min()}, max: {test_d.max()}")
    
    # Check if ray directions are normalized
    ray_lengths = np.linalg.norm(test_d, axis=-1)
    print(f"Ray direction lengths: min={ray_lengths.min()}, max={ray_lengths.max()}")
    
    # Visualize ray origins and directions
    plt.figure(figsize=(12, 5))
    
    # Plot ray origins
    plt.subplot(1, 2, 1)
    plt.scatter(test_o[test_idx, ::100, 0], test_o[test_idx, ::100, 2], alpha=0.5, s=1)
    plt.title("Ray Origins (Top-Down)")
    plt.xlabel("X")
    plt.ylabel("Z")
    plt.axis('equal')
    
    # Plot ray directions (from the center pixel)
    center_idx = test_h // 2 * test_w + test_w // 2
    plt.subplot(1, 2, 2)
    plt.quiver(test_o[test_idx, center_idx, 0].astype(np.float32), 
               test_o[test_idx, center_idx, 2].astype(np.float32),
               test_d[test_idx, center_idx, 0].astype(np.float32), 
               test_d[test_idx, center_idx, 2].astype(np.float32),
               angles='xy', scale_units='xy', scale=0.1)
    plt.title("Center Ray Direction")
    plt.xlabel("X")
    plt.ylabel("Z")
    plt.axis('equal')
    
    plt.tight_layout()
    plt.show()

# Debug ray generation
debug_ray_generation()

# Visualize a test image
print("Rendering test image...")
visualize_test_image(0)
print("If the image is still white, try adjusting tn/tf parameters or increasing nb_bins")
# Out:
# torch version:  2.6.0
# device:  mps
# Loaded 397 training images with resolution 262144 pixels
# Loaded 44 test images
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 64
#      62 # Initialize the NeRF model with more capacity
#      63 model = Nerf(hidden_dim=256, Lpos=10, Ldir=4).to(device)
# ---> 64 optimizer = torch.optim.Adam(model.parameters(), lr=5e-4)  # Lower learning rate for stability
#      65 scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[2, 4, 6], gamma=0.5)
#      67 # Training: First warmup with cropped images
#
# File ~/miniforge3/envs/NeRF/lib/python3.13/site-packages/torch/optim/adam.py:99, in Adam.__init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused)
#      85         raise ValueError("Tensor betas[1] must be 1-element")
#      87 defaults = dict(
#      88     lr=lr,
#      89     betas=betas,
#    (...)
#      97     fused=fused,
#      98 )
# ---> 99 super().__init__(params, defaults)
#     101 if fused:
#     102     if differentiable:
#
# File ~/miniforge3/envs/NeRF/lib/python3.13/site-packages/torch/optim/optimizer.py:377, in Optimizer.__init__(self, params, defaults)
#     374     param_groups = [{"params": param_groups}]
#     376 for param_group in param_groups:
# --> 377     self.add_param_group(cast(dict, param_group))
#     379 # Allows _cuda_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#     380 # which I don't think exists
#     381 # https://github.com/pytorch/pytorch/issues/72948
#     382 self._warned_capturable_if_run_uncaptured = True
#
# File ~/miniforge3/envs/NeRF/lib/python3.13/site-packages/torch/_compile.py:27, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      25 disable_fn = getattr(fn, "__dynamo_disable", None)
#      26 if disable_fn is None:
# ---> 27     import torch._dynamo
#      29     disable_fn = torch._dynamo.disable(fn, recursive)
#      30     fn.__dynamo_disable = disable_fn
#
# File ~/miniforge3/envs/NeRF/lib/python3.13/site-packages/torch/_dynamo/__init__.py:3
#       1 import torch
# ----> 3 from . import convert_frame, eval_frame, resume_execution
#       4 from .backends.registry import list_backends, lookup_backend, register_backend
#       5 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File ~/miniforge3/envs/NeRF/lib/python3.13/site-packages/torch/_dynamo/convert_frame.py:33
#      31 from torch._C._dynamo.guards import GlobalStateGuard
#      32 from torch._dynamo.distributed import get_compile_pg
# ---> 33 from torch._dynamo.symbolic_convert import TensorifyState
#      34 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      35 from torch._logging import structured
#
# File ~/miniforge3/envs/NeRF/lib/python3.13/site-packages/torch/_dynamo/symbolic_convert.py:27
#      25 import torch
#      26 import torch._logging
# ---> 27 from torch._dynamo.exc import TensorifyScalarRestartAnalysis
#      28 from torch._guards import tracing, TracingContext
#      30 from . import config, exc, logging as torchdynamo_logging, trace_rules, variables
#
# File ~/miniforge3/envs/NeRF/lib/python3.13/site-packages/torch/_dynamo/exc.py:11
#       8 import torch._guards
#      10 from . import config
# ---> 11 from .utils import counters
#      14 if TYPE_CHECKING:
#      15     from torch._guards import CompileId
#
# File ~/miniforge3/envs/NeRF/lib/python3.13/site-packages/torch/_dynamo/utils.py:111
#     105 # NOTE: Make sure `NP_SUPPORTED_MODULES` and `NP_TO_TNP_MODULE` are in sync.
#     106 if np:
#     107     NP_SUPPORTED_MODULES: Tuple[types.ModuleType, ...] = (
#     108         np,
#     109         np.fft,
#     110         np.linalg,
# --> 111         np.random,
#     112     )
#     114     NP_TO_TNP_MODULE = {
#     115         np: tnp,
#     116         np.fft: tnp.fft,
#     117         np.linalg: tnp.linalg,
#     118         np.random: tnp.random,
#     119     }
#     120 else:
#
# File ~/miniforge3/envs/NeRF/lib/python3.13/site-packages/numpy/__init__.py:340, in __getattr__(attr)
#     338     return dtypes
#     339 elif attr == "random":
# --> 340     import numpy.random as random
#     341     return random
#     342 elif attr == "polynomial":
#
# File ~/miniforge3/envs/NeRF/lib/python3.13/site-packages/numpy/random/__init__.py:180
#     126 __all__ = [
#     127     'beta',
#     128     'binomial',
#    (...)
#     176     'zipf',
#     177 ]
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _pickle
#     181 from . import _common
#     182 from . import _bounded_integers
#
# File ~/miniforge3/envs/NeRF/lib/python3.13/site-packages/numpy/random/_pickle.py:2
#       1 from .bit_generator import BitGenerator
# ----> 2 from .mtrand import RandomState
#       3 from ._philox import Philox
#       4 from ._pcg64 import PCG64, PCG64DXSM
#
# File numpy/random/mtrand.pyx:4760, in init numpy.random.mtrand()
#
# File numpy/random/mtrand.pyx:183, in numpy.random.mtrand.RandomState.__init__()
#
# File _mt19937.pyx:132, in numpy.random._mt19937.MT19937.__init__()
#
# File ~/miniforge3/envs/NeRF/lib/python3.13/site-packages/numpy/_core/_ufunc_config.py:479, in errstate.__call__.<locals>.inner(*args, **kwargs)
#     476 _token = _extobj_contextvar.set(extobj)
#     477 try:
#     478     # Call the original, decorated, function:
# --> 479     return func(*args, **kwargs)
#     480 finally:
#     481     _extobj_contextvar.reset(_token)
#
# KeyboardInterrupt:

# %%
import torch
import numpy as np
from nerfvis import scene
from model import Nerf

# Define device
if torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")
print(f"Using device: {device}")

# Initialize the model with the SAME architecture as the trained model
# Match these parameters to those used during training
model = Nerf(hidden_dim=256, Lpos=10, Ldir=4).to(device)

# Load the saved weights
model.load_state_dict(torch.load('nerf_model_weights.pth', map_location=device))
model.eval()

# Create a scene
scene.set_title("NeRF Visualization")

# Add coordinate axes for reference
scene.add_axes("axes", length=1.0)

# Define a 3D grid of points to sample your NeRF
# Use a smaller resolution if you encounter memory issues
resolution = 128  # Number of points per dimension (reduced from 512 for faster processing)
# Adjust the sampled area to match the scene's bounding box
x = np.linspace(-1, 5, resolution)
y = np.linspace(-1, 5, resolution)
z = np.linspace(-1, 5, resolution)
xx, yy, zz = np.meshgrid(x, y, z, indexing='ij')
points = np.stack([xx.flatten(), yy.flatten(), zz.flatten()], axis=-1).astype(np.float32)  # Explicitly use float32

# For each point, we'll use multiple viewing directions
num_directions = 6
directions = []
for i in range(num_directions):
    # Create evenly distributed viewing directions
    theta = np.pi * i / num_directions
    phi = 2 * np.pi * i / num_directions
    dx = np.sin(theta) * np.cos(phi)
    dy = np.sin(theta) * np.sin(phi)
    dz = np.cos(theta)
    directions.append([dx, dy, dz])

directions = np.array(directions, dtype=np.float32)  # Explicitly use float32
directions_tensor = torch.tensor(directions, dtype=torch.float32, device=device)

# Evaluate NeRF at these points and directions
print("Evaluating NeRF at grid points...")
valid_points = []
valid_colors = []

batch_size = 2000  # Reduced batch size for MPS memory constraints
num_batches = (points.shape[0] + batch_size - 1) // batch_size

# Density threshold - adjust this if you're getting too many or too few points
threshold = 0.1  # Start with a lower threshold

with torch.no_grad():
    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = min((i + 1) * batch_size, points.shape[0])
        batch_points = torch.tensor(points[start_idx:end_idx], dtype=torch.float32, device=device)
        
        batch_colors_list = []
        batch_densities_list = []
        
        for direction in directions_tensor:
            # Expand direction to match the batch size
            batch_dirs = direction.expand(batch_points.size(0), -1)
            
            # Get model output
            colors, density = model.intersect(batch_points, batch_dirs)  # Using intersect method
            
            batch_colors_list.append(colors)
            batch_densities_list.append(density)
        
        # Average colors across different view directions
        avg_colors = torch.stack(batch_colors_list).mean(dim=0)
        # Use maximum density across different view directions
        max_densities = torch.stack(batch_densities_list).max(dim=0)[0]
        
        # Get flattened density values
        density_vals = max_densities.flatten()
        
        # Find points above threshold
        batch_valid_indices = torch.where(density_vals > threshold)[0].cpu().numpy()
        
        if len(batch_valid_indices) > 0:
            # Get valid points and colors for this batch
            batch_valid_points = points[start_idx:end_idx][batch_valid_indices]
            batch_valid_colors = avg_colors[batch_valid_indices].cpu().numpy()
            
            # Make sure colors are in valid range [0,1]
            batch_valid_colors = np.clip(batch_valid_colors, 0, 1)
            
            # Append to our valid points and colors
            valid_points.append(batch_valid_points)
            valid_colors.append(batch_valid_colors)
            
        print(f"Processed batch {i+1}/{num_batches} - Found {len(batch_valid_indices)} valid points")

# Combine all valid points and colors
if valid_points:
    all_valid_points = np.vstack(valid_points)
    all_valid_colors = np.vstack(valid_colors)
    
    print(f"Total valid points: {len(all_valid_points)}")
    
    # Visualize the points
    scene.add_points(
        name="nerf_high_density",
        points=all_valid_points,
        vert_color=all_valid_colors,
        point_size=2.0
    )
    
    # Optionally, add camera positions from your dataset
    # This would require loading transforms.json and extracting camera positions
    try:
        import json
        with open('transforms.json', 'r') as f:
            transforms = json.load(f)
        
        camera_positions = []
        for frame in transforms['frames']:
            c2w = np.array(frame['transform_matrix'], dtype=np.float32)
            pos = c2w[:3, 3]
            camera_positions.append(pos)
        
        camera_positions = np.array(camera_positions, dtype=np.float32)
        
        # Add camera positions to the scene
        scene.add_points(
            name="cameras",
            points=camera_positions,
            vert_color=np.array([[0, 1, 0]] * len(camera_positions), dtype=np.float32),  # Green for cameras
            point_size=8.0
        )
        
        print(f"Added {len(camera_positions)} camera positions to the scene")
    except Exception as e:
        print(f"Could not add camera positions: {e}")
else:
    print("No high-density points found. Try lowering the threshold.")
    
# Add some reference objects to show the volume we're sampling
scene.add_wireframe_cube("bounds", scale=6.0, color=[0.5, 0.5, 0.5])

# Display the scene
scene.display(port=8888, open_browser=True)
# Out:
# Using device: mps
# Evaluating NeRF at grid points...
# Processed batch 1/1049 - Found 15 valid points
# Processed batch 2/1049 - Found 13 valid points
# Processed batch 3/1049 - Found 1 valid points
# Processed batch 4/1049 - Found 74 valid points
# Processed batch 5/1049 - Found 10 valid points
# Processed batch 6/1049 - Found 71 valid points
# Processed batch 7/1049 - Found 0 valid points
# Processed batch 8/1049 - Found 31 valid points
# Processed batch 9/1049 - Found 30 valid points
# Processed batch 10/1049 - Found 18 valid points
# Processed batch 11/1049 - Found 1 valid points
# Processed batch 12/1049 - Found 34 valid points
# Processed batch 13/1049 - Found 5 valid points
# Processed batch 14/1049 - Found 49 valid points
# Processed batch 15/1049 - Found 0 valid points
# Processed batch 16/1049 - Found 14 valid points
# Processed batch 17/1049 - Found 4 valid points
# Processed batch 18/1049 - Found 18 valid points
# Processed batch 19/1049 - Found 1 valid points
# Processed batch 20/1049 - Found 46 valid points
# Processed batch 21/1049 - Found 3 valid points
# Processed batch 22/1049 - Found 65 valid points
# Processed batch 23/1049 - Found 7 valid points
# Processed batch 24/1049 - Found 4 valid points
# Processed batch 25/1049 - Found 4 valid points
# Processed batch 26/1049 - Found 40 valid points
# Processed batch 27/1049 - Found 0 valid points
# Processed batch 28/1049 - Found 22 valid points
# Processed batch 29/1049 - Found 9 valid points
# Processed batch 30/1049 - Found 26 valid points
# Processed batch 31/1049 - Found 17 valid points
# Processed batch 32/1049 - Found 2 valid points
# Processed batch 33/1049 - Found 2 valid points
# Processed batch 34/1049 - Found 49 valid points
# Processed batch 35/1049 - Found 25 valid points
# Processed batch 36/1049 - Found 23 valid points
# Processed batch 37/1049 - Found 57 valid points
# Processed batch 38/1049 - Found 15 valid points
# Processed batch 39/1049 - Found 91 valid points
# Processed batch 40/1049 - Found 0 valid points
# Processed batch 41/1049 - Found 11 valid points
# Processed batch 42/1049 - Found 105 valid points
# Processed batch 43/1049 - Found 91 valid points
# Processed batch 44/1049 - Found 18 valid points
# Processed batch 45/1049 - Found 113 valid points
# Processed batch 46/1049 - Found 25 valid points
# Processed batch 47/1049 - Found 153 valid points
# Processed batch 48/1049 - Found 3 valid points
# Processed batch 49/1049 - Found 48 valid points
# Processed batch 50/1049 - Found 50 valid points
# Processed batch 51/1049 - Found 127 valid points
# Processed batch 52/1049 - Found 25 valid points
# Processed batch 53/1049 - Found 179 valid points
# Processed batch 54/1049 - Found 53 valid points
# Processed batch 55/1049 - Found 208 valid points
# Processed batch 56/1049 - Found 13 valid points
# Processed batch 57/1049 - Found 75 valid points
# Processed batch 58/1049 - Found 48 valid points
# Processed batch 59/1049 - Found 103 valid points
# Processed batch 60/1049 - Found 41 valid points
# Processed batch 61/1049 - Found 154 valid points
# Processed batch 62/1049 - Found 60 valid points
# Processed batch 63/1049 - Found 159 valid points
# Processed batch 64/1049 - Found 61 valid points
# Processed batch 65/1049 - Found 48 valid points
# Processed batch 66/1049 - Found 36 valid points
# Processed batch 67/1049 - Found 32 valid points
# Processed batch 68/1049 - Found 50 valid points
# Processed batch 69/1049 - Found 99 valid points
# Processed batch 70/1049 - Found 69 valid points
# Processed batch 71/1049 - Found 85 valid points
# Processed batch 72/1049 - Found 97 valid points
# Processed batch 73/1049 - Found 12 valid points
# Processed batch 74/1049 - Found 83 valid points
# Processed batch 75/1049 - Found 51 valid points
# Processed batch 76/1049 - Found 47 valid points
# Processed batch 77/1049 - Found 73 valid points
# Processed batch 78/1049 - Found 95 valid points
# Processed batch 79/1049 - Found 81 valid points
# Processed batch 80/1049 - Found 76 valid points
# Processed batch 81/1049 - Found 24 valid points
# Processed batch 82/1049 - Found 67 valid points
# Processed batch 83/1049 - Found 59 valid points
# Processed batch 84/1049 - Found 34 valid points
# Processed batch 85/1049 - Found 53 valid points
# Processed batch 86/1049 - Found 108 valid points
# Processed batch 87/1049 - Found 56 valid points
# Processed batch 88/1049 - Found 115 valid points
# Processed batch 89/1049 - Found 18 valid points
# Processed batch 90/1049 - Found 49 valid points
# Processed batch 91/1049 - Found 1 valid points
# Processed batch 92/1049 - Found 16 valid points
# Processed batch 93/1049 - Found 3 valid points
# Processed batch 94/1049 - Found 41 valid points
# Processed batch 95/1049 - Found 1 valid points
# Processed batch 96/1049 - Found 50 valid points
# Processed batch 97/1049 - Found 1 valid points
# Processed batch 98/1049 - Found 3 valid points
# Processed batch 99/1049 - Found 16 valid points
# Processed batch 100/1049 - Found 83 valid points
# Processed batch 101/1049 - Found 10 valid points
# Processed batch 102/1049 - Found 85 valid points
# Processed batch 103/1049 - Found 5 valid points
# Processed batch 104/1049 - Found 94 valid points
# Processed batch 105/1049 - Found 13 valid points
# Processed batch 106/1049 - Found 12 valid points
# Processed batch 107/1049 - Found 53 valid points
# Processed batch 108/1049 - Found 114 valid points
# Processed batch 109/1049 - Found 29 valid points
# Processed batch 110/1049 - Found 94 valid points
# Processed batch 111/1049 - Found 39 valid points
# Processed batch 112/1049 - Found 110 valid points
# Processed batch 113/1049 - Found 63 valid points
# Processed batch 114/1049 - Found 19 valid points
# Processed batch 115/1049 - Found 62 valid points
# Processed batch 116/1049 - Found 148 valid points
# Processed batch 117/1049 - Found 104 valid points
# Processed batch 118/1049 - Found 113 valid points
# Processed batch 119/1049 - Found 113 valid points
# Processed batch 120/1049 - Found 137 valid points
# Processed batch 121/1049 - Found 161 valid points
# Processed batch 122/1049 - Found 34 valid points
# Processed batch 123/1049 - Found 89 valid points
# Processed batch 124/1049 - Found 73 valid points
# Processed batch 125/1049 - Found 109 valid points
# Processed batch 126/1049 - Found 53 valid points
# Processed batch 127/1049 - Found 130 valid points
# Processed batch 128/1049 - Found 65 valid points
# Processed batch 129/1049 - Found 185 valid points
# Processed batch 130/1049 - Found 12 valid points
# Processed batch 131/1049 - Found 51 valid points
# Processed batch 132/1049 - Found 43 valid points
# Processed batch 133/1049 - Found 147 valid points
# Processed batch 134/1049 - Found 50 valid points
# Processed batch 135/1049 - Found 157 valid points
# Processed batch 136/1049 - Found 37 valid points
# Processed batch 137/1049 - Found 207 valid points
# Processed batch 138/1049 - Found 12 valid points
# Processed batch 139/1049 - Found 51 valid points
# Processed batch 140/1049 - Found 47 valid points
# Processed batch 141/1049 - Found 132 valid points
# Processed batch 142/1049 - Found 76 valid points
# Processed batch 143/1049 - Found 167 valid points
# Processed batch 144/1049 - Found 60 valid points
# Processed batch 145/1049 - Found 176 valid points
# Processed batch 146/1049 - Found 32 valid points
# Processed batch 147/1049 - Found 67 valid points
# Processed batch 148/1049 - Found 103 valid points
# Processed batch 149/1049 - Found 193 valid points
# Processed batch 150/1049 - Found 125 valid points
# Processed batch 151/1049 - Found 173 valid points
# Processed batch 152/1049 - Found 81 valid points
# Processed batch 153/1049 - Found 204 valid points
# Processed batch 154/1049 - Found 95 valid points
# Processed batch 155/1049 - Found 53 valid points
# Processed batch 156/1049 - Found 75 valid points
# Processed batch 157/1049 - Found 112 valid points
# Processed batch 158/1049 - Found 66 valid points
# Processed batch 159/1049 - Found 91 valid points
# Processed batch 160/1049 - Found 69 valid points
# Processed batch 161/1049 - Found 98 valid points
# Processed batch 162/1049 - Found 117 valid points
# Processed batch 163/1049 - Found 5 valid points
# Processed batch 164/1049 - Found 47 valid points
# Processed batch 165/1049 - Found 161 valid points
# Processed batch 166/1049 - Found 166 valid points
# Processed batch 167/1049 - Found 61 valid points
# Processed batch 168/1049 - Found 115 valid points
# Processed batch 169/1049 - Found 52 valid points
# Processed batch 170/1049 - Found 189 valid points
# Processed batch 171/1049 - Found 7 valid points
# Processed batch 172/1049 - Found 39 valid points
# Processed batch 173/1049 - Found 155 valid points
# Processed batch 174/1049 - Found 279 valid points
# Processed batch 175/1049 - Found 133 valid points
# Processed batch 176/1049 - Found 214 valid points
# Processed batch 177/1049 - Found 134 valid points
# Processed batch 178/1049 - Found 272 valid points
# Processed batch 179/1049 - Found 51 valid points
# Processed batch 180/1049 - Found 120 valid points
# Processed batch 181/1049 - Found 192 valid points
# Processed batch 182/1049 - Found 340 valid points
# Processed batch 183/1049 - Found 258 valid points
# Processed batch 184/1049 - Found 281 valid points
# Processed batch 185/1049 - Found 241 valid points
# Processed batch 186/1049 - Found 321 valid points
# Processed batch 187/1049 - Found 219 valid points
# Processed batch 188/1049 - Found 219 valid points
# Processed batch 189/1049 - Found 161 valid points
# Processed batch 190/1049 - Found 217 valid points
# Processed batch 191/1049 - Found 242 valid points
# Processed batch 192/1049 - Found 221 valid points
# Processed batch 193/1049 - Found 219 valid points
# Processed batch 194/1049 - Found 242 valid points
# Processed batch 195/1049 - Found 203 valid points
# Processed batch 196/1049 - Found 138 valid points
# Processed batch 197/1049 - Found 141 valid points
# Processed batch 198/1049 - Found 64 valid points
# Processed batch 199/1049 - Found 182 valid points
# Processed batch 200/1049 - Found 139 valid points
# Processed batch 201/1049 - Found 156 valid points
# Processed batch 202/1049 - Found 135 valid points
# Processed batch 203/1049 - Found 184 valid points
# Processed batch 204/1049 - Found 64 valid points
# Processed batch 205/1049 - Found 75 valid points
# Processed batch 206/1049 - Found 16 valid points
# Processed batch 207/1049 - Found 75 valid points
# Processed batch 208/1049 - Found 64 valid points
# Processed batch 209/1049 - Found 84 valid points
# Processed batch 210/1049 - Found 49 valid points
# Processed batch 211/1049 - Found 104 valid points
# Processed batch 212/1049 - Found 24 valid points
# Processed batch 213/1049 - Found 33 valid points
# Processed batch 214/1049 - Found 35 valid points
# Processed batch 215/1049 - Found 51 valid points
# Processed batch 216/1049 - Found 60 valid points
# Processed batch 217/1049 - Found 79 valid points
# Processed batch 218/1049 - Found 42 valid points
# Processed batch 219/1049 - Found 92 valid points
# Processed batch 220/1049 - Found 58 valid points
# Processed batch 221/1049 - Found 45 valid points
# Processed batch 222/1049 - Found 24 valid points
# Processed batch 223/1049 - Found 47 valid points
# Processed batch 224/1049 - Found 55 valid points
# Processed batch 225/1049 - Found 88 valid points
# Processed batch 226/1049 - Found 50 valid points
# Processed batch 227/1049 - Found 88 valid points
# Processed batch 228/1049 - Found 53 valid points
# Processed batch 229/1049 - Found 37 valid points
# Processed batch 230/1049 - Found 15 valid points
# Processed batch 231/1049 - Found 16 valid points
# Processed batch 232/1049 - Found 22 valid points
# Processed batch 233/1049 - Found 46 valid points
# Processed batch 234/1049 - Found 11 valid points
# Processed batch 235/1049 - Found 61 valid points
# Processed batch 236/1049 - Found 17 valid points
# Processed batch 237/1049 - Found 7 valid points
# Processed batch 238/1049 - Found 9 valid points
# Processed batch 239/1049 - Found 12 valid points
# Processed batch 240/1049 - Found 21 valid points
# Processed batch 241/1049 - Found 25 valid points
# Processed batch 242/1049 - Found 13 valid points
# Processed batch 243/1049 - Found 18 valid points
# Processed batch 244/1049 - Found 30 valid points
# Processed batch 245/1049 - Found 1 valid points
# Processed batch 246/1049 - Found 23 valid points
# Processed batch 247/1049 - Found 65 valid points
# Processed batch 248/1049 - Found 55 valid points
# Processed batch 249/1049 - Found 50 valid points
# Processed batch 250/1049 - Found 64 valid points
# Processed batch 251/1049 - Found 28 valid points
# Processed batch 252/1049 - Found 73 valid points
# Processed batch 253/1049 - Found 19 valid points
# Processed batch 254/1049 - Found 33 valid points
# Processed batch 255/1049 - Found 51 valid points
# Processed batch 256/1049 - Found 70 valid points
# Processed batch 257/1049 - Found 62 valid points
# Processed batch 258/1049 - Found 111 valid points
# Processed batch 259/1049 - Found 31 valid points
# Processed batch 260/1049 - Found 118 valid points
# Processed batch 261/1049 - Found 22 valid points
# Processed batch 262/1049 - Found 43 valid points
# Processed batch 263/1049 - Found 19 valid points
# Processed batch 264/1049 - Found 20 valid points
# Processed batch 265/1049 - Found 34 valid points
# Processed batch 266/1049 - Found 86 valid points
# Processed batch 267/1049 - Found 15 valid points
# Processed batch 268/1049 - Found 72 valid points
# Processed batch 269/1049 - Found 6 valid points
# Processed batch 270/1049 - Found 23 valid points
# Processed batch 271/1049 - Found 1 valid points
# Processed batch 272/1049 - Found 3 valid points
# Processed batch 273/1049 - Found 8 valid points
# Processed batch 274/1049 - Found 11 valid points
# Processed batch 275/1049 - Found 3 valid points
# Processed batch 276/1049 - Found 6 valid points
# Processed batch 277/1049 - Found 4 valid points
# Processed batch 278/1049 - Found 4 valid points
# Processed batch 279/1049 - Found 19 valid points
# Processed batch 280/1049 - Found 2 valid points
# Processed batch 281/1049 - Found 21 valid points
# Processed batch 282/1049 - Found 27 valid points
# Processed batch 283/1049 - Found 15 valid points
# Processed batch 284/1049 - Found 21 valid points
# Processed batch 285/1049 - Found 11 valid points
# Processed batch 286/1049 - Found 10 valid points
# Processed batch 287/1049 - Found 33 valid points
# Processed batch 288/1049 - Found 18 valid points
# Processed batch 289/1049 - Found 33 valid points
# Processed batch 290/1049 - Found 44 valid points
# Processed batch 291/1049 - Found 43 valid points
# Processed batch 292/1049 - Found 36 valid points
# Processed batch 293/1049 - Found 42 valid points
# Processed batch 294/1049 - Found 12 valid points
# Processed batch 295/1049 - Found 33 valid points
# Processed batch 296/1049 - Found 21 valid points
# Processed batch 297/1049 - Found 25 valid points
# Processed batch 298/1049 - Found 9 valid points
# Processed batch 299/1049 - Found 51 valid points
# Processed batch 300/1049 - Found 4 valid points
# Processed batch 301/1049 - Found 48 valid points
# Processed batch 302/1049 - Found 0 valid points
# Processed batch 303/1049 - Found 7 valid points
# Processed batch 304/1049 - Found 5 valid points
# Processed batch 305/1049 - Found 29 valid points
# Processed batch 306/1049 - Found 1 valid points
# Processed batch 307/1049 - Found 41 valid points
# Processed batch 308/1049 - Found 0 valid points
# Processed batch 309/1049 - Found 38 valid points
# Processed batch 310/1049 - Found 0 valid points
# Processed batch 311/1049 - Found 6 valid points
# Processed batch 312/1049 - Found 34 valid points
# Processed batch 313/1049 - Found 54 valid points
# Processed batch 314/1049 - Found 22 valid points
# Processed batch 315/1049 - Found 75 valid points
# Processed batch 316/1049 - Found 9 valid points
# Processed batch 317/1049 - Found 60 valid points
# Processed batch 318/1049 - Found 6 valid points
# Processed batch 319/1049 - Found 26 valid points
# Processed batch 320/1049 - Found 38 valid points
# Processed batch 321/1049 - Found 42 valid points
# Processed batch 322/1049 - Found 73 valid points
# Processed batch 323/1049 - Found 74 valid points
# Processed batch 324/1049 - Found 57 valid points
# Processed batch 325/1049 - Found 73 valid points
# Processed batch 326/1049 - Found 68 valid points
# Processed batch 327/1049 - Found 19 valid points
# Processed batch 328/1049 - Found 50 valid points
# Processed batch 329/1049 - Found 2 valid points
# Processed batch 330/1049 - Found 34 valid points
# Processed batch 331/1049 - Found 41 valid points
# Processed batch 332/1049 - Found 62 valid points
# Processed batch 333/1049 - Found 53 valid points
# Processed batch 334/1049 - Found 64 valid points
# Processed batch 335/1049 - Found 14 valid points
# Processed batch 336/1049 - Found 34 valid points
# Processed batch 337/1049 - Found 0 valid points
# Processed batch 338/1049 - Found 0 valid points
# Processed batch 339/1049 - Found 0 valid points
# Processed batch 340/1049 - Found 1 valid points
# Processed batch 341/1049 - Found 0 valid points
# Processed batch 342/1049 - Found 3 valid points
# Processed batch 343/1049 - Found 0 valid points
# Processed batch 344/1049 - Found 0 valid points
# Processed batch 345/1049 - Found 0 valid points
# Processed batch 346/1049 - Found 0 valid points
# Processed batch 347/1049 - Found 0 valid points
# Processed batch 348/1049 - Found 0 valid points
# Processed batch 349/1049 - Found 0 valid points
# Processed batch 350/1049 - Found 1 valid points
# Processed batch 351/1049 - Found 0 valid points
# Processed batch 352/1049 - Found 0 valid points
# Processed batch 353/1049 - Found 0 valid points
# Processed batch 354/1049 - Found 4 valid points
# Processed batch 355/1049 - Found 6 valid points
# Processed batch 356/1049 - Found 3 valid points
# Processed batch 357/1049 - Found 3 valid points
# Processed batch 358/1049 - Found 5 valid points
# Processed batch 359/1049 - Found 9 valid points
# Processed batch 360/1049 - Found 4 valid points
# Processed batch 361/1049 - Found 0 valid points
# Processed batch 362/1049 - Found 1 valid points
# Processed batch 363/1049 - Found 1 valid points
# Processed batch 364/1049 - Found 4 valid points
# Processed batch 365/1049 - Found 2 valid points
# Processed batch 366/1049 - Found 3 valid points
# Processed batch 367/1049 - Found 2 valid points
# Processed batch 368/1049 - Found 0 valid points
# Processed batch 369/1049 - Found 2 valid points
# Processed batch 370/1049 - Found 0 valid points
# Processed batch 371/1049 - Found 0 valid points
# Processed batch 372/1049 - Found 0 valid points
# Processed batch 373/1049 - Found 0 valid points
# Processed batch 374/1049 - Found 0 valid points
# Processed batch 375/1049 - Found 1 valid points
# Processed batch 376/1049 - Found 0 valid points
# Processed batch 377/1049 - Found 0 valid points
# Processed batch 378/1049 - Found 0 valid points
# Processed batch 379/1049 - Found 2 valid points
# Processed batch 380/1049 - Found 0 valid points
# Processed batch 381/1049 - Found 9 valid points
# Processed batch 382/1049 - Found 0 valid points
# Processed batch 383/1049 - Found 8 valid points
# Processed batch 384/1049 - Found 0 valid points
# Processed batch 385/1049 - Found 1 valid points
# Processed batch 386/1049 - Found 17 valid points
# Processed batch 387/1049 - Found 15 valid points
# Processed batch 388/1049 - Found 16 valid points
# Processed batch 389/1049 - Found 34 valid points
# Processed batch 390/1049 - Found 13 valid points
# Processed batch 391/1049 - Found 37 valid points
# Processed batch 392/1049 - Found 2 valid points
# Processed batch 393/1049 - Found 8 valid points
# Processed batch 394/1049 - Found 7 valid points
# Processed batch 395/1049 - Found 12 valid points
# Processed batch 396/1049 - Found 19 valid points
# Processed batch 397/1049 - Found 94 valid points
# Processed batch 398/1049 - Found 16 valid points
# Processed batch 399/1049 - Found 76 valid points
# Processed batch 400/1049 - Found 11 valid points
# Processed batch 401/1049 - Found 33 valid points
# Processed batch 402/1049 - Found 4 valid points
# Processed batch 403/1049 - Found 0 valid points
# Processed batch 404/1049 - Found 1 valid points
# Processed batch 405/1049 - Found 16 valid points
# Processed batch 406/1049 - Found 1 valid points
# Processed batch 407/1049 - Found 11 valid points
# Processed batch 408/1049 - Found 4 valid points
# Processed batch 409/1049 - Found 0 valid points
# Processed batch 410/1049 - Found 1 valid points
# Processed batch 411/1049 - Found 0 valid points
# Processed batch 412/1049 - Found 6 valid points
# Processed batch 413/1049 - Found 6 valid points
# Processed batch 414/1049 - Found 3 valid points
# Processed batch 415/1049 - Found 5 valid points
# Processed batch 416/1049 - Found 10 valid points
# Processed batch 417/1049 - Found 0 valid points
# Processed batch 418/1049 - Found 11 valid points
# Processed batch 419/1049 - Found 13 valid points
# Processed batch 420/1049 - Found 13 valid points
# Processed batch 421/1049 - Found 25 valid points
# Processed batch 422/1049 - Found 23 valid points
# Processed batch 423/1049 - Found 22 valid points
# Processed batch 424/1049 - Found 27 valid points
# Processed batch 425/1049 - Found 3 valid points
# Processed batch 426/1049 - Found 21 valid points
# Processed batch 427/1049 - Found 12 valid points
# Processed batch 428/1049 - Found 27 valid points
# Processed batch 429/1049 - Found 8 valid points
# Processed batch 430/1049 - Found 59 valid points
# Processed batch 431/1049 - Found 12 valid points
# Processed batch 432/1049 - Found 73 valid points
# Processed batch 433/1049 - Found 0 valid points
# Processed batch 434/1049 - Found 19 valid points
# Processed batch 435/1049 - Found 10 valid points
# Processed batch 436/1049 - Found 49 valid points
# Processed batch 437/1049 - Found 0 valid points
# Processed batch 438/1049 - Found 38 valid points
# Processed batch 439/1049 - Found 0 valid points
# Processed batch 440/1049 - Found 68 valid points
# Processed batch 441/1049 - Found 0 valid points
# Processed batch 442/1049 - Found 2 valid points
# Processed batch 443/1049 - Found 13 valid points
# Processed batch 444/1049 - Found 62 valid points
# Processed batch 445/1049 - Found 2 valid points
# Processed batch 446/1049 - Found 50 valid points
# Processed batch 447/1049 - Found 3 valid points
# Processed batch 448/1049 - Found 57 valid points
# Processed batch 449/1049 - Found 13 valid points
# Processed batch 450/1049 - Found 5 valid points
# Processed batch 451/1049 - Found 81 valid points
# Processed batch 452/1049 - Found 110 valid points
# Processed batch 453/1049 - Found 133 valid points
# Processed batch 454/1049 - Found 117 valid points
# Processed batch 455/1049 - Found 80 valid points
# Processed batch 456/1049 - Found 95 valid points
# Processed batch 457/1049 - Found 107 valid points
# Processed batch 458/1049 - Found 53 valid points
# Processed batch 459/1049 - Found 82 valid points
# Processed batch 460/1049 - Found 62 valid points
# Processed batch 461/1049 - Found 100 valid points
# Processed batch 462/1049 - Found 105 valid points
# Processed batch 463/1049 - Found 124 valid points
# Processed batch 464/1049 - Found 96 valid points
# Processed batch 465/1049 - Found 134 valid points
# Processed batch 466/1049 - Found 45 valid points
# Processed batch 467/1049 - Found 79 valid points
# Processed batch 468/1049 - Found 12 valid points
# Processed batch 469/1049 - Found 26 valid points
# Processed batch 470/1049 - Found 47 valid points
# Processed batch 471/1049 - Found 64 valid points
# Processed batch 472/1049 - Found 36 valid points
# Processed batch 473/1049 - Found 73 valid points
# Processed batch 474/1049 - Found 14 valid points
# Processed batch 475/1049 - Found 29 valid points
# Processed batch 476/1049 - Found 0 valid points
# Processed batch 477/1049 - Found 0 valid points
# Processed batch 478/1049 - Found 0 valid points
# Processed batch 479/1049 - Found 0 valid points
# Processed batch 480/1049 - Found 0 valid points
# Processed batch 481/1049 - Found 2 valid points
# Processed batch 482/1049 - Found 0 valid points
# Processed batch 483/1049 - Found 0 valid points
# Processed batch 484/1049 - Found 0 valid points
# Processed batch 485/1049 - Found 0 valid points
# Processed batch 486/1049 - Found 3 valid points
# Processed batch 487/1049 - Found 0 valid points
# Processed batch 488/1049 - Found 1 valid points
# Processed batch 489/1049 - Found 0 valid points
# Processed batch 490/1049 - Found 2 valid points
# Processed batch 491/1049 - Found 0 valid points
# Processed batch 492/1049 - Found 0 valid points
# Processed batch 493/1049 - Found 0 valid points
# Processed batch 494/1049 - Found 6 valid points
# Processed batch 495/1049 - Found 0 valid points
# Processed batch 496/1049 - Found 2 valid points
# Processed batch 497/1049 - Found 0 valid points
# Processed batch 498/1049 - Found 4 valid points
# Processed batch 499/1049 - Found 4 valid points
# Processed batch 500/1049 - Found 0 valid points
# Processed batch 501/1049 - Found 0 valid points
# Processed batch 502/1049 - Found 0 valid points
# Processed batch 503/1049 - Found 0 valid points
# Processed batch 504/1049 - Found 1 valid points
# Processed batch 505/1049 - Found 0 valid points
# Processed batch 506/1049 - Found 1 valid points
# Processed batch 507/1049 - Found 0 valid points
# Processed batch 508/1049 - Found 0 valid points
# Processed batch 509/1049 - Found 0 valid points
# Processed batch 510/1049 - Found 0 valid points
# Processed batch 511/1049 - Found 0 valid points
# Processed batch 512/1049 - Found 0 valid points
# Processed batch 513/1049 - Found 0 valid points
# Processed batch 514/1049 - Found 0 valid points
# Processed batch 515/1049 - Found 0 valid points
# Processed batch 516/1049 - Found 0 valid points
# Processed batch 517/1049 - Found 5 valid points
# Processed batch 518/1049 - Found 1 valid points
# Processed batch 519/1049 - Found 3 valid points
# Processed batch 520/1049 - Found 1 valid points
# Processed batch 521/1049 - Found 1 valid points
# Processed batch 522/1049 - Found 1 valid points
# Processed batch 523/1049 - Found 0 valid points
# Processed batch 524/1049 - Found 0 valid points
# Processed batch 525/1049 - Found 4 valid points
# Processed batch 526/1049 - Found 4 valid points
# Processed batch 527/1049 - Found 7 valid points
# Processed batch 528/1049 - Found 12 valid points
# Processed batch 529/1049 - Found 3 valid points
# Processed batch 530/1049 - Found 7 valid points
# Processed batch 531/1049 - Found 2 valid points
# Processed batch 532/1049 - Found 5 valid points
# Processed batch 533/1049 - Found 2 valid points
# Processed batch 534/1049 - Found 2 valid points
# Processed batch 535/1049 - Found 3 valid points
# Processed batch 536/1049 - Found 7 valid points
# Processed batch 537/1049 - Found 3 valid points
# Processed batch 538/1049 - Found 4 valid points
# Processed batch 539/1049 - Found 2 valid points
# Processed batch 540/1049 - Found 0 valid points
# Processed batch 541/1049 - Found 1 valid points
# Processed batch 542/1049 - Found 0 valid points
# Processed batch 543/1049 - Found 0 valid points
# Processed batch 544/1049 - Found 0 valid points
# Processed batch 545/1049 - Found 0 valid points
# Processed batch 546/1049 - Found 0 valid points
# Processed batch 547/1049 - Found 0 valid points
# Processed batch 548/1049 - Found 0 valid points
# Processed batch 549/1049 - Found 0 valid points
# Processed batch 550/1049 - Found 0 valid points
# Processed batch 551/1049 - Found 0 valid points
# Processed batch 552/1049 - Found 0 valid points
# Processed batch 553/1049 - Found 0 valid points
# Processed batch 554/1049 - Found 0 valid points
# Processed batch 555/1049 - Found 0 valid points
# Processed batch 556/1049 - Found 0 valid points
# Processed batch 557/1049 - Found 1 valid points
# Processed batch 558/1049 - Found 5 valid points
# Processed batch 559/1049 - Found 6 valid points
# Processed batch 560/1049 - Found 2 valid points
# Processed batch 561/1049 - Found 9 valid points
# Processed batch 562/1049 - Found 6 valid points
# Processed batch 563/1049 - Found 9 valid points
# Processed batch 564/1049 - Found 0 valid points
# Processed batch 565/1049 - Found 3 valid points
# Processed batch 566/1049 - Found 1 valid points
# Processed batch 567/1049 - Found 12 valid points
# Processed batch 568/1049 - Found 0 valid points
# Processed batch 569/1049 - Found 23 valid points
# Processed batch 570/1049 - Found 0 valid points
# Processed batch 571/1049 - Found 19 valid points
# Processed batch 572/1049 - Found 0 valid points
# Processed batch 573/1049 - Found 5 valid points
# Processed batch 574/1049 - Found 0 valid points
# Processed batch 575/1049 - Found 10 valid points
# Processed batch 576/1049 - Found 0 valid points
# Processed batch 577/1049 - Found 7 valid points
# Processed batch 578/1049 - Found 0 valid points
# Processed batch 579/1049 - Found 8 valid points
# Processed batch 580/1049 - Found 0 valid points
# Processed batch 581/1049 - Found 0 valid points
# Processed batch 582/1049 - Found 5 valid points
# Processed batch 583/1049 - Found 17 valid points
# Processed batch 584/1049 - Found 11 valid points
# Processed batch 585/1049 - Found 22 valid points
# Processed batch 586/1049 - Found 10 valid points
# Processed batch 587/1049 - Found 7 valid points
# Processed batch 588/1049 - Found 25 valid points
# Processed batch 589/1049 - Found 0 valid points
# Processed batch 590/1049 - Found 10 valid points
# Processed batch 591/1049 - Found 58 valid points
# Processed batch 592/1049 - Found 49 valid points
# Processed batch 593/1049 - Found 26 valid points
# Processed batch 594/1049 - Found 73 valid points
# Processed batch 595/1049 - Found 26 valid points
# Processed batch 596/1049 - Found 87 valid points
# Processed batch 597/1049 - Found 7 valid points
# Processed batch 598/1049 - Found 30 valid points
# Processed batch 599/1049 - Found 3 valid points
# Processed batch 600/1049 - Found 26 valid points
# Processed batch 601/1049 - Found 7 valid points
# Processed batch 602/1049 - Found 94 valid points
# Processed batch 603/1049 - Found 27 valid points
# Processed batch 604/1049 - Found 91 valid points
# Processed batch 605/1049 - Found 4 valid points
# Processed batch 606/1049 - Found 38 valid points
# Processed batch 607/1049 - Found 0 valid points
# Processed batch 608/1049 - Found 0 valid points
# Processed batch 609/1049 - Found 0 valid points
# Processed batch 610/1049 - Found 4 valid points
# Processed batch 611/1049 - Found 0 valid points
# Processed batch 612/1049 - Found 7 valid points
# Processed batch 613/1049 - Found 1 valid points
# Processed batch 614/1049 - Found 0 valid points
# Processed batch 615/1049 - Found 0 valid points
# Processed batch 616/1049 - Found 0 valid points
# Processed batch 617/1049 - Found 0 valid points
# Processed batch 618/1049 - Found 0 valid points
# Processed batch 619/1049 - Found 0 valid points
# Processed batch 620/1049 - Found 1 valid points
# Processed batch 621/1049 - Found 2 valid points
# Processed batch 622/1049 - Found 0 valid points
# Processed batch 623/1049 - Found 1 valid points
# Processed batch 624/1049 - Found 0 valid points
# Processed batch 625/1049 - Found 8 valid points
# Processed batch 626/1049 - Found 5 valid points
# Processed batch 627/1049 - Found 1 valid points
# Processed batch 628/1049 - Found 9 valid points
# Processed batch 629/1049 - Found 7 valid points
# Processed batch 630/1049 - Found 9 valid points
# Processed batch 631/1049 - Found 2 valid points
# Processed batch 632/1049 - Found 0 valid points
# Processed batch 633/1049 - Found 4 valid points
# Processed batch 634/1049 - Found 2 valid points
# Processed batch 635/1049 - Found 7 valid points
# Processed batch 636/1049 - Found 1 valid points
# Processed batch 637/1049 - Found 6 valid points
# Processed batch 638/1049 - Found 0 valid points
# Processed batch 639/1049 - Found 2 valid points
# Processed batch 640/1049 - Found 0 valid points
# Processed batch 641/1049 - Found 0 valid points
# Processed batch 642/1049 - Found 0 valid points
# Processed batch 643/1049 - Found 0 valid points
# Processed batch 644/1049 - Found 0 valid points
# Processed batch 645/1049 - Found 2 valid points
# Processed batch 646/1049 - Found 0 valid points
# Processed batch 647/1049 - Found 0 valid points
# Processed batch 648/1049 - Found 0 valid points
# Processed batch 649/1049 - Found 5 valid points
# Processed batch 650/1049 - Found 0 valid points
# Processed batch 651/1049 - Found 1 valid points
# Processed batch 652/1049 - Found 0 valid points
# Processed batch 653/1049 - Found 6 valid points
# Processed batch 654/1049 - Found 0 valid points
# Processed batch 655/1049 - Found 0 valid points
# Processed batch 656/1049 - Found 31 valid points
# Processed batch 657/1049 - Found 34 valid points
# Processed batch 658/1049 - Found 19 valid points
# Processed batch 659/1049 - Found 51 valid points
# Processed batch 660/1049 - Found 5 valid points
# Processed batch 661/1049 - Found 71 valid points
# Processed batch 662/1049 - Found 16 valid points
# Processed batch 663/1049 - Found 11 valid points
# Processed batch 664/1049 - Found 19 valid points
# Processed batch 665/1049 - Found 21 valid points
# Processed batch 666/1049 - Found 31 valid points
# Processed batch 667/1049 - Found 67 valid points
# Processed batch 668/1049 - Found 35 valid points
# Processed batch 669/1049 - Found 69 valid points
# Processed batch 670/1049 - Found 72 valid points
# Processed batch 671/1049 - Found 4 valid points
# Processed batch 672/1049 - Found 27 valid points
# Processed batch 673/1049 - Found 2 valid points
# Processed batch 674/1049 - Found 10 valid points
# Processed batch 675/1049 - Found 13 valid points
# Processed batch 676/1049 - Found 25 valid points
# Processed batch 677/1049 - Found 9 valid points
# Processed batch 678/1049 - Found 60 valid points
# Processed batch 679/1049 - Found 0 valid points
# Processed batch 680/1049 - Found 7 valid points
# Processed batch 681/1049 - Found 0 valid points
# Processed batch 682/1049 - Found 10 valid points
# Processed batch 683/1049 - Found 1 valid points
# Processed batch 684/1049 - Found 16 valid points
# Processed batch 685/1049 - Found 0 valid points
# Processed batch 686/1049 - Found 29 valid points
# Processed batch 687/1049 - Found 0 valid points
# Processed batch 688/1049 - Found 6 valid points
# Processed batch 689/1049 - Found 41 valid points
# Processed batch 690/1049 - Found 27 valid points
# Processed batch 691/1049 - Found 21 valid points
# Processed batch 692/1049 - Found 57 valid points
# Processed batch 693/1049 - Found 10 valid points
# Processed batch 694/1049 - Found 67 valid points
# Processed batch 695/1049 - Found 3 valid points
# Processed batch 696/1049 - Found 34 valid points
# Processed batch 697/1049 - Found 23 valid points
# Processed batch 698/1049 - Found 57 valid points
# Processed batch 699/1049 - Found 23 valid points
# Processed batch 700/1049 - Found 76 valid points
# Processed batch 701/1049 - Found 16 valid points
# Processed batch 702/1049 - Found 82 valid points
# Processed batch 703/1049 - Found 16 valid points
# Processed batch 704/1049 - Found 14 valid points
# Processed batch 705/1049 - Found 20 valid points
# Processed batch 706/1049 - Found 54 valid points
# Processed batch 707/1049 - Found 6 valid points
# Processed batch 708/1049 - Found 37 valid points
# Processed batch 709/1049 - Found 2 valid points
# Processed batch 710/1049 - Found 30 valid points
# Processed batch 711/1049 - Found 29 valid points
# Processed batch 712/1049 - Found 0 valid points
# Processed batch 713/1049 - Found 9 valid points
# Processed batch 714/1049 - Found 54 valid points
# Processed batch 715/1049 - Found 41 valid points
# Processed batch 716/1049 - Found 15 valid points
# Processed batch 717/1049 - Found 32 valid points
# Processed batch 718/1049 - Found 4 valid points
# Processed batch 719/1049 - Found 56 valid points
# Processed batch 720/1049 - Found 0 valid points
# Processed batch 721/1049 - Found 15 valid points
# Processed batch 722/1049 - Found 129 valid points
# Processed batch 723/1049 - Found 157 valid points
# Processed batch 724/1049 - Found 109 valid points
# Processed batch 725/1049 - Found 135 valid points
# Processed batch 726/1049 - Found 75 valid points
# Processed batch 727/1049 - Found 153 valid points
# Processed batch 728/1049 - Found 39 valid points
# Processed batch 729/1049 - Found 78 valid points
# Processed batch 730/1049 - Found 68 valid points
# Processed batch 731/1049 - Found 119 valid points
# Processed batch 732/1049 - Found 123 valid points
# Processed batch 733/1049 - Found 145 valid points
# Processed batch 734/1049 - Found 71 valid points
# Processed batch 735/1049 - Found 155 valid points
# Processed batch 736/1049 - Found 87 valid points
# Processed batch 737/1049 - Found 86 valid points
# Processed batch 738/1049 - Found 8 valid points
# Processed batch 739/1049 - Found 19 valid points
# Processed batch 740/1049 - Found 38 valid points
# Processed batch 741/1049 - Found 52 valid points
# Processed batch 742/1049 - Found 26 valid points
# Processed batch 743/1049 - Found 41 valid points
# Processed batch 744/1049 - Found 40 valid points
# Processed batch 745/1049 - Found 19 valid points
# Processed batch 746/1049 - Found 12 valid points
# Processed batch 747/1049 - Found 0 valid points
# Processed batch 748/1049 - Found 0 valid points
# Processed batch 749/1049 - Found 0 valid points
# Processed batch 750/1049 - Found 0 valid points
# Processed batch 751/1049 - Found 0 valid points
# Processed batch 752/1049 - Found 0 valid points
# Processed batch 753/1049 - Found 0 valid points
# Processed batch 754/1049 - Found 0 valid points
# Processed batch 755/1049 - Found 0 valid points
# Processed batch 756/1049 - Found 0 valid points
# Processed batch 757/1049 - Found 0 valid points
# Processed batch 758/1049 - Found 0 valid points
# Processed batch 759/1049 - Found 0 valid points
# Processed batch 760/1049 - Found 0 valid points
# Processed batch 761/1049 - Found 0 valid points
# Processed batch 762/1049 - Found 0 valid points
# Processed batch 763/1049 - Found 0 valid points
# Processed batch 764/1049 - Found 0 valid points
# Processed batch 765/1049 - Found 0 valid points
# Processed batch 766/1049 - Found 0 valid points
# Processed batch 767/1049 - Found 0 valid points
# Processed batch 768/1049 - Found 0 valid points
# Processed batch 769/1049 - Found 0 valid points
# Processed batch 770/1049 - Found 0 valid points
# Processed batch 771/1049 - Found 0 valid points
# Processed batch 772/1049 - Found 0 valid points
# Processed batch 773/1049 - Found 0 valid points
# Processed batch 774/1049 - Found 0 valid points
# Processed batch 775/1049 - Found 0 valid points
# Processed batch 776/1049 - Found 0 valid points
# Processed batch 777/1049 - Found 0 valid points
# Processed batch 778/1049 - Found 0 valid points
# Processed batch 779/1049 - Found 0 valid points
# Processed batch 780/1049 - Found 0 valid points
# Processed batch 781/1049 - Found 0 valid points
# Processed batch 782/1049 - Found 0 valid points
# Processed batch 783/1049 - Found 0 valid points
# Processed batch 784/1049 - Found 0 valid points
# Processed batch 785/1049 - Found 0 valid points
# Processed batch 786/1049 - Found 0 valid points
# Processed batch 787/1049 - Found 0 valid points
# Processed batch 788/1049 - Found 0 valid points
# Processed batch 789/1049 - Found 0 valid points
# Processed batch 790/1049 - Found 0 valid points
# Processed batch 791/1049 - Found 0 valid points
# Processed batch 792/1049 - Found 0 valid points
# Processed batch 793/1049 - Found 0 valid points
# Processed batch 794/1049 - Found 0 valid points
# Processed batch 795/1049 - Found 0 valid points
# Processed batch 796/1049 - Found 0 valid points
# Processed batch 797/1049 - Found 0 valid points
# Processed batch 798/1049 - Found 0 valid points
# Processed batch 799/1049 - Found 0 valid points
# Processed batch 800/1049 - Found 0 valid points
# Processed batch 801/1049 - Found 0 valid points
# Processed batch 802/1049 - Found 0 valid points
# Processed batch 803/1049 - Found 0 valid points
# Processed batch 804/1049 - Found 0 valid points
# Processed batch 805/1049 - Found 0 valid points
# Processed batch 806/1049 - Found 0 valid points
# Processed batch 807/1049 - Found 0 valid points
# Processed batch 808/1049 - Found 0 valid points
# Processed batch 809/1049 - Found 0 valid points
# Processed batch 810/1049 - Found 0 valid points
# Processed batch 811/1049 - Found 0 valid points
# Processed batch 812/1049 - Found 0 valid points
# Processed batch 813/1049 - Found 0 valid points
# Processed batch 814/1049 - Found 0 valid points
# Processed batch 815/1049 - Found 0 valid points
# Processed batch 816/1049 - Found 0 valid points
# Processed batch 817/1049 - Found 0 valid points
# Processed batch 818/1049 - Found 0 valid points
# Processed batch 819/1049 - Found 0 valid points
# Processed batch 820/1049 - Found 0 valid points
# Processed batch 821/1049 - Found 0 valid points
# Processed batch 822/1049 - Found 0 valid points
# Processed batch 823/1049 - Found 0 valid points
# Processed batch 824/1049 - Found 0 valid points
# Processed batch 825/1049 - Found 0 valid points
# Processed batch 826/1049 - Found 0 valid points
# Processed batch 827/1049 - Found 0 valid points
# Processed batch 828/1049 - Found 0 valid points
# Processed batch 829/1049 - Found 0 valid points
# Processed batch 830/1049 - Found 0 valid points
# Processed batch 831/1049 - Found 0 valid points
# Processed batch 832/1049 - Found 0 valid points
# Processed batch 833/1049 - Found 0 valid points
# Processed batch 834/1049 - Found 0 valid points
# Processed batch 835/1049 - Found 0 valid points
# Processed batch 836/1049 - Found 0 valid points
# Processed batch 837/1049 - Found 0 valid points
# Processed batch 838/1049 - Found 0 valid points
# Processed batch 839/1049 - Found 0 valid points
# Processed batch 840/1049 - Found 0 valid points
# Processed batch 841/1049 - Found 0 valid points
# Processed batch 842/1049 - Found 0 valid points
# Processed batch 843/1049 - Found 0 valid points
# Processed batch 844/1049 - Found 0 valid points
# Processed batch 845/1049 - Found 0 valid points
# Processed batch 846/1049 - Found 0 valid points
# Processed batch 847/1049 - Found 0 valid points
# Processed batch 848/1049 - Found 0 valid points
# Processed batch 849/1049 - Found 0 valid points
# Processed batch 850/1049 - Found 0 valid points
# Processed batch 851/1049 - Found 0 valid points
# Processed batch 852/1049 - Found 0 valid points
# Processed batch 853/1049 - Found 0 valid points
# Processed batch 854/1049 - Found 0 valid points
# Processed batch 855/1049 - Found 0 valid points
# Processed batch 856/1049 - Found 0 valid points
# Processed batch 857/1049 - Found 0 valid points
# Processed batch 858/1049 - Found 0 valid points
# Processed batch 859/1049 - Found 0 valid points
# Processed batch 860/1049 - Found 0 valid points
# Processed batch 861/1049 - Found 0 valid points
# Processed batch 862/1049 - Found 0 valid points
# Processed batch 863/1049 - Found 0 valid points
# Processed batch 864/1049 - Found 0 valid points
# Processed batch 865/1049 - Found 0 valid points
# Processed batch 866/1049 - Found 0 valid points
# Processed batch 867/1049 - Found 0 valid points
# Processed batch 868/1049 - Found 0 valid points
# Processed batch 869/1049 - Found 0 valid points
# Processed batch 870/1049 - Found 0 valid points
# Processed batch 871/1049 - Found 0 valid points
# Processed batch 872/1049 - Found 0 valid points
# Processed batch 873/1049 - Found 0 valid points
# Processed batch 874/1049 - Found 0 valid points
# Processed batch 875/1049 - Found 0 valid points
# Processed batch 876/1049 - Found 0 valid points
# Processed batch 877/1049 - Found 0 valid points
# Processed batch 878/1049 - Found 0 valid points
# Processed batch 879/1049 - Found 0 valid points
# Processed batch 880/1049 - Found 0 valid points
# Processed batch 881/1049 - Found 0 valid points
# Processed batch 882/1049 - Found 0 valid points
# Processed batch 883/1049 - Found 0 valid points
# Processed batch 884/1049 - Found 0 valid points
# Processed batch 885/1049 - Found 0 valid points
# Processed batch 886/1049 - Found 0 valid points
# Processed batch 887/1049 - Found 0 valid points
# Processed batch 888/1049 - Found 0 valid points
# Processed batch 889/1049 - Found 0 valid points
# Processed batch 890/1049 - Found 0 valid points
# Processed batch 891/1049 - Found 0 valid points
# Processed batch 892/1049 - Found 0 valid points
# Processed batch 893/1049 - Found 0 valid points
# Processed batch 894/1049 - Found 0 valid points
# Processed batch 895/1049 - Found 0 valid points
# Processed batch 896/1049 - Found 0 valid points
# Processed batch 897/1049 - Found 0 valid points
# Processed batch 898/1049 - Found 0 valid points
# Processed batch 899/1049 - Found 0 valid points
# Processed batch 900/1049 - Found 0 valid points
# Processed batch 901/1049 - Found 0 valid points
# Processed batch 902/1049 - Found 0 valid points
# Processed batch 903/1049 - Found 0 valid points
# Processed batch 904/1049 - Found 0 valid points
# Processed batch 905/1049 - Found 0 valid points
# Processed batch 906/1049 - Found 0 valid points
# Processed batch 907/1049 - Found 0 valid points
# Processed batch 908/1049 - Found 0 valid points
# Processed batch 909/1049 - Found 0 valid points
# Processed batch 910/1049 - Found 0 valid points
# Processed batch 911/1049 - Found 0 valid points
# Processed batch 912/1049 - Found 0 valid points
# Processed batch 913/1049 - Found 0 valid points
# Processed batch 914/1049 - Found 0 valid points
# Processed batch 915/1049 - Found 0 valid points
# Processed batch 916/1049 - Found 0 valid points
# Processed batch 917/1049 - Found 0 valid points
# Processed batch 918/1049 - Found 0 valid points
# Processed batch 919/1049 - Found 0 valid points
# Processed batch 920/1049 - Found 0 valid points
# Processed batch 921/1049 - Found 0 valid points
# Processed batch 922/1049 - Found 0 valid points
# Processed batch 923/1049 - Found 0 valid points
# Processed batch 924/1049 - Found 0 valid points
# Processed batch 925/1049 - Found 0 valid points
# Processed batch 926/1049 - Found 0 valid points
# Processed batch 927/1049 - Found 0 valid points
# Processed batch 928/1049 - Found 0 valid points
# Processed batch 929/1049 - Found 0 valid points
# Processed batch 930/1049 - Found 0 valid points
# Processed batch 931/1049 - Found 0 valid points
# Processed batch 932/1049 - Found 0 valid points
# Processed batch 933/1049 - Found 0 valid points
# Processed batch 934/1049 - Found 0 valid points
# Processed batch 935/1049 - Found 0 valid points
# Processed batch 936/1049 - Found 0 valid points
# Processed batch 937/1049 - Found 0 valid points
# Processed batch 938/1049 - Found 0 valid points
# Processed batch 939/1049 - Found 0 valid points
# Processed batch 940/1049 - Found 0 valid points
# Processed batch 941/1049 - Found 0 valid points
# Processed batch 942/1049 - Found 0 valid points
# Processed batch 943/1049 - Found 0 valid points
# Processed batch 944/1049 - Found 0 valid points
# Processed batch 945/1049 - Found 0 valid points
# Processed batch 946/1049 - Found 0 valid points
# Processed batch 947/1049 - Found 0 valid points
# Processed batch 948/1049 - Found 0 valid points
# Processed batch 949/1049 - Found 0 valid points
# Processed batch 950/1049 - Found 0 valid points
# Processed batch 951/1049 - Found 0 valid points
# Processed batch 952/1049 - Found 0 valid points
# Processed batch 953/1049 - Found 0 valid points
# Processed batch 954/1049 - Found 0 valid points
# Processed batch 955/1049 - Found 0 valid points
# Processed batch 956/1049 - Found 0 valid points
# Processed batch 957/1049 - Found 0 valid points
# Processed batch 958/1049 - Found 0 valid points
# Processed batch 959/1049 - Found 0 valid points
# Processed batch 960/1049 - Found 0 valid points
# Processed batch 961/1049 - Found 0 valid points
# Processed batch 962/1049 - Found 0 valid points
# Processed batch 963/1049 - Found 0 valid points
# Processed batch 964/1049 - Found 0 valid points
# Processed batch 965/1049 - Found 0 valid points
# Processed batch 966/1049 - Found 0 valid points
# Processed batch 967/1049 - Found 0 valid points
# Processed batch 968/1049 - Found 0 valid points
# Processed batch 969/1049 - Found 0 valid points
# Processed batch 970/1049 - Found 1 valid points
# Processed batch 971/1049 - Found 0 valid points
# Processed batch 972/1049 - Found 0 valid points
# Processed batch 973/1049 - Found 1 valid points
# Processed batch 974/1049 - Found 0 valid points
# Processed batch 975/1049 - Found 0 valid points
# Processed batch 976/1049 - Found 0 valid points
# Processed batch 977/1049 - Found 4 valid points
# Processed batch 978/1049 - Found 0 valid points
# Processed batch 979/1049 - Found 2 valid points
# Processed batch 980/1049 - Found 0 valid points
# Processed batch 981/1049 - Found 0 valid points
# Processed batch 982/1049 - Found 0 valid points
# Processed batch 983/1049 - Found 0 valid points
# Processed batch 984/1049 - Found 0 valid points
# Processed batch 985/1049 - Found 0 valid points
# Processed batch 986/1049 - Found 0 valid points
# Processed batch 987/1049 - Found 0 valid points
# Processed batch 988/1049 - Found 0 valid points
# Processed batch 989/1049 - Found 0 valid points
# Processed batch 990/1049 - Found 0 valid points
# Processed batch 991/1049 - Found 0 valid points
# Processed batch 992/1049 - Found 5 valid points
# Processed batch 993/1049 - Found 9 valid points
# Processed batch 994/1049 - Found 0 valid points
# Processed batch 995/1049 - Found 11 valid points
# Processed batch 996/1049 - Found 0 valid points
# Processed batch 997/1049 - Found 11 valid points
# Processed batch 998/1049 - Found 0 valid points
# Processed batch 999/1049 - Found 2 valid points
# Processed batch 1000/1049 - Found 17 valid points
# Processed batch 1001/1049 - Found 12 valid points
# Processed batch 1002/1049 - Found 35 valid points
# Processed batch 1003/1049 - Found 31 valid points
# Processed batch 1004/1049 - Found 12 valid points
# Processed batch 1005/1049 - Found 28 valid points
# Processed batch 1006/1049 - Found 26 valid points
# Processed batch 1007/1049 - Found 13 valid points
# Processed batch 1008/1049 - Found 10 valid points
# Processed batch 1009/1049 - Found 0 valid points
# Processed batch 1010/1049 - Found 3 valid points
# Processed batch 1011/1049 - Found 6 valid points
# Processed batch 1012/1049 - Found 6 valid points
# Processed batch 1013/1049 - Found 2 valid points
# Processed batch 1014/1049 - Found 13 valid points
# Processed batch 1015/1049 - Found 1 valid points
# Processed batch 1016/1049 - Found 1 valid points
# Processed batch 1017/1049 - Found 0 valid points
# Processed batch 1018/1049 - Found 0 valid points
# Processed batch 1019/1049 - Found 0 valid points
# Processed batch 1020/1049 - Found 0 valid points
# Processed batch 1021/1049 - Found 0 valid points
# Processed batch 1022/1049 - Found 0 valid points
# Processed batch 1023/1049 - Found 0 valid points
# Processed batch 1024/1049 - Found 0 valid points
# Processed batch 1025/1049 - Found 0 valid points
# Processed batch 1026/1049 - Found 0 valid points
# Processed batch 1027/1049 - Found 0 valid points
# Processed batch 1028/1049 - Found 0 valid points
# Processed batch 1029/1049 - Found 0 valid points
# Processed batch 1030/1049 - Found 0 valid points
# Processed batch 1031/1049 - Found 0 valid points
# Processed batch 1032/1049 - Found 0 valid points
# Processed batch 1033/1049 - Found 0 valid points
# Processed batch 1034/1049 - Found 0 valid points
# Processed batch 1035/1049 - Found 0 valid points
# Processed batch 1036/1049 - Found 0 valid points
# Processed batch 1037/1049 - Found 0 valid points
# Processed batch 1038/1049 - Found 0 valid points
# Processed batch 1039/1049 - Found 0 valid points
# Processed batch 1040/1049 - Found 0 valid points
# Processed batch 1041/1049 - Found 0 valid points
# Processed batch 1042/1049 - Found 0 valid points
# Processed batch 1043/1049 - Found 0 valid points
# Processed batch 1044/1049 - Found 0 valid points
# Processed batch 1045/1049 - Found 0 valid points
# Processed batch 1046/1049 - Found 0 valid points
# Processed batch 1047/1049 - Found 0 valid points
# Processed batch 1048/1049 - Found 0 valid points
# Processed batch 1049/1049 - Found 0 valid points
# Total valid points: 30162
# Added 100 camera positions to the scene
# Serving localhost:8888
# 127.0.0.1 - - [10/Mar/2025 11:31:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Mar/2025 11:31:37] code 404, message File not found
# 127.0.0.1 - - [10/Mar/2025 11:31:37] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [10/Mar/2025 11:31:37] "GET /volrend.draw.npz HTTP/1.1" 200 -
# nervfvis-server interrupted
# ('nerfvis_scenes/NeRFVisualization', 'http://localhost:8888')
