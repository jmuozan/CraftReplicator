# %%
import torch
import numpy as np
import os
import imageio
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

from dataset import get_rays
from rendering import rendering
from model import Voxels, Nerf
from ml_helpers import training
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 9
#       6 from torch.utils.data import DataLoader
#       8 from dataset import get_rays
# ----> 9 from rendering import rendering, test_render
#      10 from model import Voxels, Nerf
#      11 from ml_helpers import training
#
# ImportError: cannot import name 'test_render' from 'rendering' (/Users/jorgemuyo/Desktop/CraftReplicator/rendering.py)

# %% [markdown]
# # Camera / Dataset

# %%
batch_size = 1024

o, d, target_px_values= get_rays('fox', mode='train')
dataloader = DataLoader(torch.cat((torch.from_numpy(o).reshape(-1, 3),
                                   torch.from_numpy(d).reshape(-1, 3),
                                   torch.from_numpy(target_px_values).reshape(-1, 3)), dim=1),
                       batch_size=batch_size, shuffle=True)

dataloader_warmup = DataLoader(torch.cat((torch.from_numpy(o).reshape(90, 400, 400, 3)[:, 100:300, 100:300, :].reshape(-1, 3),
                                   torch.from_numpy(d).reshape(90, 400, 400, 3)[:, 100:300, 100:300, :].reshape(-1, 3),
                                   torch.from_numpy(target_px_values).reshape(90, 400, 400, 3)[:, 100:300, 100:300, :].reshape(-1, 3)), dim=1),
                       batch_size=batch_size, shuffle=True)

# %% [markdown]
# # Model

# %%
img = rendering(model, torch.from_numpy(o[-1]), torch.from_numpy(d[-1]), 8, 12)

plt.imshow(img.reshape(400, 400, 3).data.cpu().numpy())

# %% [markdown]
# # Training

# %%
if torch.backends.mps.is_available():
   mps_device = torch.device("mps")
   x = torch.ones(1, device=mps_device)
   print (x)
else:
   print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')

# %%
# APPLE SILLICON 
# ml_helpers transformation float32 2 float64

device = 'mps'

tn = 8
tf = 12
nb_epochs = 15
lr = 1e-3
gamma = .5
nb_bins = 100

model = Nerf().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[5, 10], gamma=gamma)

training_loss = training(model, optimizer, scheduler, tn, tf, nb_bins, nb_epochs, dataloader_warmup, device=device)
plt.plot(training_loss)
training_loss = training(model, optimizer, scheduler, tn, tf, nb_bins, nb_epochs, dataloader, device=device)
# Out:
# 100%|███████████████████████████████████████████████████████| 3516/3516 [10:33<00:00,  5.55it/s]
# 100%|█████████████████████████████████████████████████████| 14063/14063 [41:46<00:00,  5.61it/s]

# %%
img = rendering(model, 
                torch.from_numpy(o[1]).to(torch.float32).to(device),  # Convert after tensor creation
                torch.from_numpy(d[1]).to(torch.float32).to(device), 
                tn, tf, nb_bins=100, device=device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 img = rendering(model,
#       2                 torch.from_numpy(o[1]).to(torch.float32).to(device),  # Convert after tensor creation
#       3                 torch.from_numpy(d[1]).to(torch.float32).to(device),
#       4                 tn, tf, nb_bins=100, device=device)
#
# File ~/Desktop/CraftReplicator/rendering.py:13, in rendering(model, rays_o, rays_d, tn, tf, nb_bins, device, white_bckgr)
#      10 t = torch.linspace(tn, tf, nb_bins).to(device) # [nb_bins]
#      11 delta = torch.cat((t[1:] - t[:-1], torch.tensor([1e10], device=device)))
# ---> 13 x = rays_o.unsqueeze(1) + t.unsqueeze(0).unsqueeze(-1) * rays_d.unsqueeze(1) # [nb_rays, nb_bins, 3]
#      15 colors, density = model.intersect(x.reshape(-1, 3), rays_d.expand(x.shape[1], x.shape[0], 3).transpose(0, 1).reshape(-1, 3))
#      17 colors = colors.reshape((x.shape[0], nb_bins, 3)) # [nb_rays, nb_bins, 3]
#
# RuntimeError: MPS backend out of memory (MPS allocated: 18.07 GB, other allocations: 704.00 KB, max allowed: 18.13 GB). Tried to allocate 183.11 MB on private pool. Use PYTORCH_MPS_HIGH_WATERMARK_RATIO=0.0 to disable upper limit for memory allocations (may cause system failure).

# %%
img = test_render(model, 
                 torch.from_numpy(o[1]).to(torch.float32),
                 torch.from_numpy(d[1]).to(torch.float32),
                 tn, tf,
                 nb_bins=100,
                 chunk_size=20)  # Adjust chunk_size if needed

plt.imshow(img.cpu().numpy())
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 img = test_render(model,
#       2                  torch.from_numpy(o[1]).to(torch.float32),
#       3                  torch.from_numpy(d[1]).to(torch.float32),
#       4                  tn, tf,
#       5                  nb_bins=100,
#       6                  chunk_size=20)  # Adjust chunk_size if needed
#       8 plt.imshow(img.cpu().numpy())
#       9 plt.show()
#
# NameError: name 'test_render' is not defined

# %%
plt.imshow(img.reshape(400, 400, 3).data.cpu().numpy())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.imshow(img.reshape(400, 400, 3).data.cpu().numpy())
#
# NameError: name 'img' is not defined

# %%
plt.plot(training_loss)
torch.save(model, 'model_nerfs')

# %% [markdown]
# # Rendering
